# %%
import pandas as pd
df = pd.read_csv("car_sell_price - Sheet1.csv")

# %%
df.head()
# Out:
#    Milage  Age(years)  Sell Price($)
# 0   69000           6          18000
# 1   35000           3          34000
# 2   57000           5          26100
# 3   22500           2          40000
# 4   46000           4          31500

# %%
 import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Milage'],df['Sell Price($)'])
plt.show()

# %%
plt.scatter(df['Age(years)'],df['Sell Price($)'])
plt.show()

# %%
x = df[['Milage', 'Age(years)']]
y = df['Sell Price($)']

# %%
x.head()
# Out:
#    Milage  Age(years)
# 0   69000           6
# 1   35000           3
# 2   57000           5
# 3   22500           2
# 4   46000           4

# %%
y.head()
# Out:
# 0    18000
# 1    34000
# 2    26100
# 3    40000
# 4    31500
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2 )

# %%
len(x_train)
# Out:
# 16

# %%
len(x_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([17531.93946695, 16173.74265717, 27647.12495581, 22080.20840771])

# %%
y_test
# Out:
# 11    19500
# 10    18700
# 19    28200
# 9     22000
# Name: Sell Price($), dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.809734558387838
